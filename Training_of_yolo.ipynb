# %%
import os
os.chdir('/content/drive/MyDrive/License_plate_detection')

# %%
ls
# Out:
# CCPD2020.zip                         images_labeled.zip  zip_data.zip
# Copy_Number_plate_recognition.ipynb  yolov5/

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %%
# %%bash
# cd yolov5
# pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 KB 4.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 KB 8.0 MB/s eta 0:00:00
# ...

# %%
os.chdir('yolov5')

# %%
# !python train.py --data data.yaml --cfg yolov5s.yaml --batch-size 32 --name Model --epochs 50
# Out:
# 2023-04-04 20:45:35.178522: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-04 20:45:36.108166: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...

# %%
# !python export.py --weights --weights runs/train/Model/weights/best.pt --include onnx --simplify --opset 12
# Out:
# benchmarks.py    data.yaml   __pycache__/      setup.cfg
# CITATION.cff     detect.py   README.md         train.py
# classify/        export.py   README.zh-CN.md   tutorial.ipynb
# CONTRIBUTING.md  hubconf.py  requirements.txt  utils/
# data/            LICENSE     runs/             val.py
# data_images/     models/     segment/          yolov5s.pt

# %%
# !python export.py --weights runs/train/Model2/weights/best.pt --include torchscript onnx
# Out:
# export: data=data/coco128.yaml, weights=['runs/train/Model2/weights/best.pt'], imgsz=[640, 640], batch_size=1, device=cpu, half=False, inplace=False, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=17, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['torchscript', 'onnx']
# YOLOv5 🚀 v7.0-134-g23c4923 Python-3.9.16 torch-2.0.0+cu118 CPU
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
#
# PyTorch: starting from runs/train/Model2/weights/best.pt with output shape (1, 25200, 6) (13.8 MB)
#
# TorchScript: starting export with torch 2.0.0+cu118...
# TorchScript: export success ✅ 3.3s, saved as runs/train/Model2/weights/best.torchscript (27.2 MB)
# requirements: YOLOv5 requirement "onnx>=1.12.0" not found, attempting AutoUpdate...
# ...
